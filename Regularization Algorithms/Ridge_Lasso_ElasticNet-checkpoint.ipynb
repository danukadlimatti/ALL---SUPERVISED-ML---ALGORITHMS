# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
boston_pd = pd.read_csv('boston.csv')

# %%
boston_pd
# Out:
#      Unnamed: 0     CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  \
# 0             0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0
# 1             1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0
# 2             2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0
# 3             3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0
# 4             4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0
# ..          ...      ...   ...    ...   ...    ...    ...   ...     ...  ...
# 501         501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0
# 502         502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0
# 503         503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0
# 504         504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0
# 505         505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0
#
# ...

# %%
boston_pd=boston_pd.iloc[:,1:]
boston_pd
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT  House Price
# 0       15.3  396.90   4.98         24.0
# ...

# %%
# input 
X = boston_pd.iloc[:, :-1] 

#output 
Y = boston_pd.iloc[:, -1] 
# boston_pd.head()

# %%
X

# %%
# boston_pd.to_csv('boston.csv')

# %%
Y

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X,Y,test_size=0.25,random_state=1)

(x_train.shape, y_train.shape,x_test.shape, y_test.shape)
# Out:
# ((379, 13), (379,), (127, 13), (127,))

# %%
x_train

# %%
# Apply multiple Linear Regression Model
from sklearn.linear_model import LinearRegression
lreg = LinearRegression() # model
lreg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
# Generate Prediction on test set 
lreg_y_pred = lreg.predict(x_test)

# %%
y_test

# %%
lreg_y_pred

# %%
lreg_y_pred.shape

# %%
# calculating Mean Squared Error (mse) 
mean_squared_error = np.mean((lreg_y_pred - y_test)**2) 
print("Mean squared Error on test set : ", mean_squared_error)

y_pred1 = lreg.predict(x_train) 

mean_squared_error = np.mean((y_pred1 - y_train)**2) 
print("Mean Squared Error on Training set", mean_squared_error)
# Out:
# Mean squared Error on test set :  21.89776539604954
# Mean Squared Error on Training set 22.477983821877896

# %%
from sklearn.metrics import r2_score
r2_score(y_test,lreg_y_pred)
# Out:
# 0.7789410172622853

# %% [markdown]
# # user testing

# %%
df.shape

# %%
l = x_train.columns
p = np.array([0.04527,0.0,12.0,0.0,0.673,6.120,76.7,2.2875,1.0,273.0,21.0,396.9,9.08])
df = pd.DataFrame([p],index=[0])
lreg.predict(df)
# Out:
# C:\Users\USER\anaconda31\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([20.0326957])

# %%
df

# %%
# Putting together the coefficient and their corrsponding variable names 
x_train.columns
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT'],
#       dtype='object')

# %%
lreg_coefficient = pd.DataFrame()
lreg_coefficient["Columns"] = x_train.columns 
lreg_coefficient
# Out:
#     Columns
# 0      CRIM
# 1        ZN
# 2     INDUS
# 3      CHAS
# 4       NOX
# 5        RM
# 6       AGE
# 7       DIS
# 8       RAD
# 9       TAX
# 10  PTRATIO
# 11        B
# 12    LSTAT

# %%
lreg.coef_
# Out:
# array([-1.14428903e-01,  5.71299780e-02,  3.83002824e-02,  2.42854641e+00,
#        -2.12326236e+01,  2.87723416e+00,  6.91118094e-03, -1.47158266e+00,
#         3.05784197e-01, -1.06750361e-02, -9.96138270e-01,  6.27746234e-03,
#        -5.57414427e-01])

# %%
lreg_coefficient['Coefficient Estimate'] = pd.Series(lreg.coef_)
lreg_coefficient
# Out:
#     Columns  Coefficient Estimate
# 0      CRIM             -0.114429
# 1        ZN              0.057130
# 2     INDUS              0.038300
# 3      CHAS              2.428546
# 4       NOX            -21.232624
# 5        RM              2.877234
# 6       AGE              0.006911
# 7       DIS             -1.471583
# 8       RAD              0.305784
# 9       TAX             -0.010675
# 10  PTRATIO             -0.996138
# 11        B              0.006277
# 12    LSTAT             -0.557414

# %%
import seaborn as sns

sns.barplot(x='Coefficient Estimate' , y='Columns', data=lreg_coefficient)
# Out:
# <Axes: xlabel='Coefficient Estimate', ylabel='Columns'>

# %%
# import ridge regression from sklearn library 
from sklearn.linear_model import Ridge 


# Train the model 
ridgeR = Ridge(alpha =1) 
ridgeR.fit(x_train, y_train) 
y_pred = ridgeR.predict(x_test) 
# y_pred

# %%
# calculate mean square error 
mean_squared_error_ridge = np.mean((y_pred - y_test)**2) 
print("MES error: ",mean_squared_error_ridge) 

y_pred1 = ridgeR.predict(x_train) 
mean_squared_error = np.mean((y_pred1 - y_train)**2) 
print("Mean Squared Error on Training set", mean_squared_error)
# Out:
# MES error:  21.31961909196863
# Mean Squared Error on Training set 22.7749342144287

# %%
# get ridge coefficient and print them 
ridge_coefficient = pd.DataFrame() 
ridge_coefficient["Columns"]= x_train.columns 
ridge_coefficient['Coefficient Estimate'] = pd.Series(ridgeR.coef_) 
ridge_coefficient
# Out:
#     Columns  Coefficient Estimate
# 0      CRIM             -0.109313
# 1        ZN              0.058147
# 2     INDUS             -0.006579
# 3      CHAS              2.176256
# 4       NOX            -11.464816
# 5        RM              2.969484
# 6       AGE             -0.001235
# 7       DIS             -1.335581
# 8       RAD              0.286709
# 9       TAX             -0.011763
# 10  PTRATIO             -0.880356
# 11        B              0.006858
# 12    LSTAT             -0.568412

# %%
r2_score(y_test,y_pred)
# Out:
# 0.7847774316882409

# %% [markdown]
# #### # import Lasso regression from sklearn library

# %%
from sklearn.linear_model import Lasso 

# Train the model 
lasso = Lasso(alpha = 0.07) 
lasso.fit(x_train, y_train) 
y_pred1 = lasso.predict(x_test) 

# Calculate Mean Squared Error 
mean_squared_error = np.mean((y_pred1 - y_test)**2) 
print("Mean squared error on test set", mean_squared_error) 
lasso_coeff = pd.DataFrame() 
lasso_coeff["Columns"] = x_train.columns 
lasso_coeff['Coefficient Estimate'] = pd.Series(lasso.coef_) 

# print(lasso_coeff)
# Out:
# Mean squared error on test set 21.961114242769295

# %%
lasso_coeff
# Out:
#     Columns  Coefficient Estimate
# 0      CRIM             -0.102497
# 1        ZN              0.059317
# 2     INDUS             -0.049966
# 3      CHAS              1.116604
# 4       NOX             -0.000000
# 5        RM              2.935705
# 6       AGE             -0.007886
# 7       DIS             -1.139575
# 8       RAD              0.269313
# 9       TAX             -0.013440
# 10  PTRATIO             -0.751395
# 11        B              0.007558
# 12    LSTAT             -0.594322

# %%
r2_score(y_test,y_pred1)
# Out:
# 0.7783015076429155

# %%
# import model 
from sklearn.linear_model import ElasticNet 


# Train the model 
e_net = ElasticNet(alpha = 0.1,l1_ratio=0.7) 
e_net.fit(x_train, y_train) 

# calculate the prediction and mean square error 
y_pred_elastic = e_net.predict(x_test) 
mean_squared_error = np.mean((y_pred_elastic - y_test)**2) 
print("Mean Squared Error on test set", mean_squared_error) 

e_net_coeff = pd.DataFrame() 
e_net_coeff["Columns"] = x_train.columns 
e_net_coeff['Coefficient Estimate'] = pd.Series(e_net.coef_) 
e_net_coeff
# Out:
# Mean Squared Error on test set 22.68141965716151
#     Columns  Coefficient Estimate
# 0      CRIM             -0.102872
# 1        ZN              0.060422
# 2     INDUS             -0.049890
# 3      CHAS              0.812611
# 4       NOX             -0.000000
# 5        RM              2.644315
# 6       AGE             -0.005229
# 7       DIS             -1.128765
# 8       RAD              0.278552
# 9       TAX             -0.013790
# 10  PTRATIO             -0.766541
# 11        B              0.007459
# 12    LSTAT             -0.614552

# %%
y_pred_elastic1 = e_net.predict(x_train) 
mean_squared_error = np.mean((y_pred_elastic1 - y_train)**2) 
print("Mean Squared Error on Training set", mean_squared_error)
# Out:
# Mean Squared Error on Training set 24.067158498674743

# %%
r2_score(y_test,y_pred_elastic)
# Out:
# 0.7710299902398321
